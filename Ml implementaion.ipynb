# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# lets Load the bosten House price Dataset

# %%
file_path = os.path.join('BostonHousing.csv')
try:
    # 2. Load the dataset into a DataFrame
    boston = pd.read_csv(file_path)

    # 3. Success! Preview the data
    print("Dataset successfully imported!")

except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}. Check your folder name.")
# Out:
# Dataset successfully imported!

# %%
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# # Preparing the dataset

# %%
dataset = pd.DataFrame(boston)
dataset.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
dataset['Price'] = boston['medv']

# %%
dataset.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv  Price
# 0  396.90   4.98  24.0   24.0
# 1  396.90   9.14  21.6   21.6
# 2  392.83   4.03  34.7   34.7
# 3  394.63   2.94  33.4   33.4
# 4  396.90   5.33  36.2   36.2

# %%
dataset.drop('medv', axis=1, inplace=True)

# %%
dataset.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  Price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
dataset.fillna(dataset.mean(numeric_only=True), inplace=True)

# %%
dataset.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# Price      0
# dtype: int64

# %%
### EDA
## Correlation

dataset.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219261  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.310847 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.392052  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091434  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302051  0.731470
# rm      -0.219261  0.310847 -0.392052  0.091434 -0.302051  1.000000 -0.239632
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.239632  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.202268 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.210353  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292178  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.356065  0.261515
# ...

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
plt.scatter(dataset['crim'],dataset['Price'])
plt.xlabel({"Crime Rate"})
plt.ylabel({"Price"})
plt.show()

# %%
## Independent And dependent Features

dataset
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  Price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# ...

# %%
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

# %%
X.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: Price, dtype: float64

# %%
## Train test split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import r2_score
# regressor = LinearRegression()
# regressor.fit(X_train, y_train)
# y_pred = regressor.predict(X_test)
# r2_score(y_test, y_pred)

# %%
## Standardize the dataset

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.20735619, -0.49997924,  1.54801583, ...,  1.2272573 ,
#          0.42454294,  3.10807269],
#        [-0.38886492,  0.34677427, -0.58974728, ...,  0.05696346,
#          0.40185312, -0.66643035],
#        [-0.33573486, -0.49997924,  1.54801583, ...,  1.2272573 ,
#          0.39846135,  0.63936662],
#        ...,
#        [-0.38450355, -0.49997924, -0.15303077, ..., -0.30312696,
#          0.39659002, -0.30284441],
#        [-0.37511786, -0.49997924, -0.59690657, ..., -0.25811566,
#          0.37588849,  0.89967717],
#        [-0.38592298, -0.49997924, -1.00641779, ..., -0.84326258,
#          0.42454294,  0.31822262]], shape=(354, 13))

# %%
X_test
# Out:
# array([[-0.39454262, -0.49997924, -1.12239824, ..., -0.70822867,
#          0.17086147, -0.72160487],
#        [ 0.70419882, -0.49997924,  1.00534187, ...,  0.77714428,
#          0.0648977 , -0.41177872],
#        [-0.38890688, -0.49997924,  0.4025299 , ..., -0.93328518,
#          0.38758427, -0.27454978],
#        ...,
#        [ 1.61285743, -0.49997924,  1.00534187, ...,  0.77714428,
#          0.42454294,  2.59876943],
#        [-0.34350332, -0.49997924, -0.1687812 , ..., -0.03305915,
#          0.42454294, -1.11772962],
#        [-0.39902507, -0.49997924, -1.27417512, ...,  0.10197476,
#          0.39202867, -1.02294263]], shape=(152, 13))

# %%
import pickle
pickle.dump(scaler, open('scaler.pkl', 'wb'))

# %% [markdown]
# # Model training

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
## print the coefficients and the intercept

print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [-1.01137476  1.05277357  0.08840643  0.6194326  -1.86855347  2.68196683
#  -0.26963144 -3.07413465  2.1158176  -1.90378807 -2.26383588  0.58332974
#  -3.45347954]
# 22.7454802259887

# %%
### Prediction with test data
reg_pred = regressor.predict(X_test)
reg_pred
# Out:
# array([24.91566959, 23.75707314, 29.34388011, 11.99615079, 21.37214694,
#        19.20773423, 20.58656553, 21.23349327, 19.05631585, 20.33145307,
#         5.44449043, 16.90809546, 17.15470584,  5.4175344 , 40.17977784,
#        32.32002451, 22.47337889, 36.50426965, 31.01658284, 23.17739478,
#        24.75125886, 24.51590502, 20.63394606, 30.44910225, 22.34487993,
#        10.25932801, 17.4514715 , 18.27850799, 35.57823893, 20.80215458,
#        18.27257969, 17.7362469 , 19.38881576, 23.65240139, 28.96650181,
#        19.47072771, 11.12101347, 24.834314  , 18.04033627, 15.5855094 ,
#        26.22688388, 20.82093922, 22.16858603, 15.50698578, 22.61758867,
#        24.8984688 , 19.78395923, 23.05579598,  9.85991462, 24.33471582,
#        21.48069013, 17.59820997, 24.40133533, 29.93915698, 13.57193753,
#        21.55159217, 20.55549177, 15.06589274, 14.34210386, 22.13020864,
#        17.1311676 , 21.5428689 , 32.96072905, 31.35905938, 17.79840286,
# ...

# %%
##  plot a scatter plot for prediction

plt.scatter(y_test, reg_pred)
plt.show()

# %%
residuals = y_test-reg_pred

# %%
## Plot this residual

sns.displot(residuals,kind = "kde")
plt.show()

# %%
### Scatter plot with respect to prediction and residuals
## Uniform distribution
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,reg_pred))
print(mean_absolute_error(y_test,reg_pred))
print(r2_score(y_test,reg_pred))
# Out:
# 27.18938788899369
# 3.608537621866973
# 0.6734615494781888

# %% [markdown]
# # New data Prediction

# %%
df_new = dataset.iloc[0,:-1].values.reshape(1,-1)

df_new
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]])

# %%
df_new.shape
# Out:
# (1, 13)

# %%
df_new = scaler.transform(df_new)
df_new
# Out:
# c:\Users\user\Desktop\Ml Projects\Boston-House-Pricing\.conda\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.40184593,  0.26209891, -1.25556098, -0.26360274, -0.15678047,
#          0.38135938, -0.13550824,  0.15863568, -0.96459077, -0.62096677,
#         -1.4284095 ,  0.42454294, -1.05548145]])

# %%
regressor.predict(df_new)
# Out:
# array([30.28586761])

# %% [markdown]
# # Pickling The Model File For Deployment

# %%
import pickle
pickle.dump(regressor, open('regmodel.pkl','wb'))

# %%
pickled_model = pickle.load(open('regmodel.pkl','rb'))

# %%
pickled_model.predict(df_new)
# Out:
# array([30.28586761])
